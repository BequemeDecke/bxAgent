# %% [markdown]
# # implement_transformation
# This node uses a deep agent to implement the transformation class according to the transformation plan (TRANSFORMATION.md)

# %%
from pathlib import Path
import sys
import logging

logging.basicConfig(level=logging.INFO)

ROOT = Path.cwd().parent.parent
logging.info(f"Adding {ROOT} to Python path for imports in kernel.")
sys.path.insert(0, str(ROOT))  # ROOT, nicht SRC!

# Load config with changed env path
from bxagent.config import Config
config = Config.get_instance(env_path=ROOT / ".env")
# Out:
# INFO:root:Adding /Users/lukas/Masterarbeit/agents/bxAgent to Python path for imports in kernel.

# %% [markdown]
# At first some prerequisities have to be made: init the Coding Deep Agent and the transformation plan

# %%
from bxagent.agents.coding.agent import build_coding_deep_agent
from bxagent.comprehension import (
    TransformationPlan,
    FileTransformationPlanParser,
)

workspace = ROOT / ".bx-agent-workspace"
tp_md_path = workspace / "TRANSFORMATION.md"
bxtool_path = workspace / "bxTool.java"

tp = TransformationPlan.parse(
    parser=FileTransformationPlanParser(file_path=tp_md_path),
    template_path=ROOT / "templates"
)

coding_agent = build_coding_deep_agent(workspace_path=workspace)
# Out:
# Error occurred while parsing transformation plan: Transformation plan file not found at /Users/lukas/Masterarbeit/agents/bxAgent/.bx-agent-workspace/TRANSFORMATION.md

# %% [markdown]
# After that, the node can be created.

# %%
from bxagent.implementation import create_implement_transformation_node

implement_transformation = create_implement_transformation_node(coding_agent=coding_agent, optional_plan_factory=lambda: tp)

# %% [markdown]
# Now, we can test if the agent is able to implement the template accordingly.

# %%
from bxagent.implementation import ImplementationState

state = ImplementationState(
    transformation_md=tp,
    task_specification="Implement the transformation class as specified in the transformation plan.",
    written_java_files=[],
    bxtool_path=bxtool_path,
    transformation_implementation="",
    latest_validation_results=[],
    implementation_iteration=0
)

# %%
response = implement_transformation(state)
# Out:
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://chat-1.ki-awz.iisys.de/api/chat/completions "HTTP/1.1 200 OK"
# INFO:root:Agent has written the following files: [PosixPath('/transformation/de/hof/university/bxagent/transformation/TransformationConfiguration.java'), PosixPath('/transformation/de/hof/university/bxagent/transformation/FamiliesToPersonsTransformation.java'), PosixPath('/transformation/de/hof/university/bxagent/transformation/PersonsToFamiliesTransformation.java'), PosixPath('/transformation/de/hof/university/bxagent/transformation/BidirectionalTransformation.java'), PosixPath('/transformation/de/hof/university/bxagent/model/families/FamiliesPackage.java'), PosixPath('/transformation/de/hof/university/bxagent/model/families/FamilyRegister.java'), PosixPath('/transformation/de/hof/university/bxagent/model/families/Family.java'), PosixPath('/transformation/de/hof/university/bxagent/model/families/FamilyMember.java'), PosixPath('/transformation/de/hof/university/bxagent/model/families/FamiliesFactory.java'), PosixPath('/transformation/de/hof/university/bxagent/model/persons/PersonRegister.java'), PosixPath('/transformation/de/hof/university/bxagent/model/persons/Person.java'), PosixPath('/transformation/de/hof/university/bxagent/model/persons/Male.java'), PosixPath('/transformation/de/hof/university/bxagent/model/persons/Female.java'), PosixPath('/transformation/de/hof/university/bxagent/model/persons/PersonsPackage.java'), PosixPath('/transformation/de/hof/university/bxagent/model/persons/PersonsFactory.java')]
